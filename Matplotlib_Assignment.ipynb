# %% [markdown]
# <a href="https://colab.research.google.com/github/Rocketman1996/Physics-wallah-Assignment/blob/main/Matplotlib_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %%
# Matplotlib is a popular Python library for creating static, animated, and interactive visualizations in 2D and 3D.

# Data Visualization: Matplotlib allows you to create a wide range of plots and charts to visualize data, making it easier to understand and interpret.

# Exploratory Data Analysis (EDA): It is often used in the initial stages of data analysis to explore data distributions, patterns, and relationships between variables.

# Scientific Plotting: Researchers and scientists use Matplotlib to create plots for scientific publications and presentations to communicate their findings effectively.Data Visualization: Matplotlib allows you to create a wide range of plots and charts to visualize data, making it easier to understand and interpret.

# Exploratory Data Analysis (EDA): It is often used in the initial stages of data analysis to explore data distributions, patterns, and relationships between variables.

# Scientific Plotting: Researchers and scientists use Matplotlib to create plots for scientific publications and presentations to communicate their findings effectively.

# 1. line chart 2. Bar Chart 3. Pie Chart 4. Histogrm(for frequencies) 5. scatter(for relativity)

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
# Scatteer plot is basically a plot in which we get data representation as dots, dots are are basically match of x, y values respec. which is used to check the data relativity.
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.
plt.xlabel("X -a normal distribution (also known as a Gaussian distribution) ")
plt.ylabel("y -a normal distribution (also known as a Gaussian distribution) ")
plt.scatter(x,y)

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
# subplot is basically used to create ultiple plots in a single filgure. syntax is - plt.subplot(rownum, colnum, num)

# Data for line plots
x = np.array([0, 1, 2, 3, 4, 5])

# Data for four different lines
y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create a figure with four subplots arranged in a 2x2 grid
plt.figure(figsize=(10, 8))

# Subplot 1: Line Plot 1
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line Plot 1')

# Subplot 2: Line Plot 2
plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line Plot 2')

# Subplot 3: Line Plot 3
plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line Plot 3')

# Subplot 4: Line Plot 4
plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line Plot 4')

# Show the entire figure
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %%
# Bar plots are basically uses bars to represent a category for a rangge of number. It is used when we require we have categorical and numerical data to represent

import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.barh(company, profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used?
# Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %%
box1 = np.random.normal(100, 10, 200) # np.random.normal(mean, sd, num_of_values)
box2 = np.random.normal(90, 20, 200)


plt.boxplot([box1, box2], labels = [box1,box2])

# %%
box1
