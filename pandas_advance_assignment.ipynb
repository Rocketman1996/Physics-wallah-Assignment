# %% [markdown]
# <a href="https://colab.research.google.com/github/Rocketman1996/Physics-wallah-Assignment/blob/main/pandas_advance_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. List any five functions of the pandas library with execution.

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie','Rahul','David'],
    'Age': [25, 30, 22,24, 35],
    'Salary': [50000, 60000, 45000, 45000, 70000],
    'Department': ['HR', 'Engineering','Engineering', 'Marketing', 'Finance']
}

# To read a file or dataframe
my_data = pd.DataFrame(data) # to read a csv file 1.pd.read_csv 2. to read a excel pd.read_excel and for html pd.read_html

# we can use head() function to get the top details as well as we can use tail to get last few details

my_data1 = my_data.head(2)
my_data12 = my_data.tail(2)



# to get the statistics about the data we can use describe() function

my_data3 = my_data.describe()

# to access the object data type for describe function
my_data4 = my_data[my_data.dtypes[my_data.dtypes == 'object'].index].describe()

# using a group by function to get the grouped values on a mean value

my_data5 = my_data.groupby('Department')['Salary'].mean()
 # here we are getting a mean value for Engineering columns because it has multiple values

print(my_data1)

print(my_data12)

# to get the info about the data frame like data types and nulls

print(my_data.info())

print(my_data3)

print(my_data4)

print(my_data5)
# Out:
#     Name  Age  Salary   Department
# 0  Alice   25   50000           HR
# 1    Bob   30   60000  Engineering
#     Name  Age  Salary Department
# 3  Rahul   24   45000  Marketing
# 4  David   35   70000    Finance
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Age         5 non-null      int64
#  2   Salary      5 non-null      int64
#  3   Department  5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes
# None
#              Age        Salary
# count   5.000000      5.000000
# mean   27.200000  54000.000000
# std     5.263079  10839.741694
# min    22.000000  45000.000000
# 25%    24.000000  45000.000000
# 50%    25.000000  50000.000000
# 75%    30.000000  60000.000000
# max    35.000000  70000.000000
#          Name   Department
# count       5            5
# ...

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
# data1 = {
#     'A': [10, 20, 30],
#     'B': [40, 50, 60],
#     'C': [70, 80, 90]
# }
# df = pd.DataFrame(data1)

# df[1::2]
data1 = {
    'A': [10, 20, 30],
    'B': [40, 50, 60],
    'C': [70, 80, 90],
    'D': [20, 35, 65]
}
def reindexing(df):
  df = df.reindex(pd.Index(range(0, len(df),2))) # using reindex
  return df


df1 = pd.DataFrame(data1)
df2 = reindexing(df1)
df2
# Out:
#     A   B   C   D
# 0  10  40  70  20
# 2  30  60  90  65

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.
# For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should
# calculate and print the sum of the first three values, which is 60.

# %%
#using a for loop

data = { 'values': [10, 20, 30, 40, 50]}
df1 = pd.DataFrame(data)
df1

def xyz(df):
  sum_of_the_first_threevalues = 0
  for i in range(3):
    sum_of_the_first_threevalues += df1['values'][i]
  return sum_of_the_first_threevalues

xyz(df1)
# Out:
# 60

# %%
# simply accessing the values column setting the range till 3rd and using .sum()
def xyz1(df12):
  sum_of_the_first_threevalues = df12['values'][0:3].sum()
  return sum_of_the_first_threevalues

data = { 'values': [10, 20, 30, 40, 50]}
df1 = pd.DataFrame(data)
df1

xyz1(df1)
# Out:
# 60

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
import pandas as pd

def add_word_count_column(df):
    # Split each row's text into words and count the number of words
    df['Word_Count'] = df['Text'].apply(lambda x: len(str(x).split())) # using str(x) to convert to text even if it is not
    # using split to split the string by whilte spaces and let to get the count.

    return df

# Example usage:
data = {'Text': ['This is a sample sentence.', 'Count the words here.', 'Another example.']}

df = pd.DataFrame(data)
add_word_count_column(df)
# Out:
#                          Text  Word_Count
# 0  This is a sample sentence.           5
# 1       Count the words here.           4
# 2            Another example.           2

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %%
df = pd.DataFrame(data = {
    'Name': ['Alice', 'Bob', 'Charlie','Rahul','David'],
    'Age': [25, 30, 22,24, 35],
    'Salary': [50000, 60000, 45000, 45000, 70000],
    'Department': ['HR', 'Engineering','Engineering', 'Marketing', 'Finance']
})
a = df.shape
b = df.size
print(a,b)

# so it's clear that size gives us no of rows * no of columns which is 20 here
# while shape tells us no of rows and columns respectively
# Out:
# (5, 4) 20

# %% [markdown]
# Q6. Which function of pandas do we use to read an excel file?

# %%
# # we use pd.read_excel("file_location")
# a = pd.read_excel('/content/LUSID Excel - Setting up your market data (1).xlsx')
# Just paste the location of the file in.

# %% [markdown]
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.

# %%
def splitter(df):
  df['Username'] = df['Email'].str.split('@').str[0] # using str.split('@') to to break the string into two parts at @ then getting the first string using str[0]
  return df

data = {'Email': ['alice@example.com', 'bob@gmail.com', 'charlie@yahoo.com']}
df = pd.DataFrame(data)
df
splitter(df)
# Out:
#                Email Username
# 0  alice@example.com    alice
# 1      bob@gmail.com      bob
# 2  charlie@yahoo.com  charlie

# %% [markdown]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.
# For example, if df contains the following values:
# A B C
# 0 3 5 1
# 1 8 2 7
# 2 6 9 4
# 3 2 3 5
# 4 9 1 2
# Your function should select the following rows: A B C
# 1 8 2 7
# 4 9 1 2
# The function should return a new DataFrame that contains only the selected rows.

# %%
# there seems to be a small error in the que that it should select  row number 1, 2 and 4th for the conditions in the example.

df1 = pd.DataFrame(data = {
    'Name': ['Alice', 'Bob', 'Charlie','Rahul','David'],
    'Age': [25, 30, 22,24, 35],
    'Salary': [50000, 60000, 45000, 45000, 70000],
    'Department': ['HR', 'Engineering','Engineering', 'Marketing', 'Finance']
})

def selector(df):
  df = df[(df['Age']> 25) & (df['Salary']> 45000)]
  return df

selector(df1)

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
df = pd.DataFrame(data = { 'Values': [10, 20, 30, 40, 50]})

Stat_Summary = df.describe()
Summary

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
data = {'Date': ['2023-09-01', '2023-09-02', '2023-09-03', '2023-09-04', '2023-09-05', '2023-09-06', '2023-09-07'],
        'Sales': [100, 150, 200, 250, 300, 350, 400]}

def xy(df):
   # in case if we reuire to sort the values for any columns
  df = df.sort_values(by = 'Date')

  df['MovingAverage'] = df['Sales'].rolling(window = 7, min_periods = 1).mean() # using rolling function to get the rolling values till 7 and then next 7 values like, min period 1
  # means even if we have missing values in sales columns as long as we have atleast one value it'll perform the action.
  return df

df = pd.DataFrame(data)
xy(df)
# Out:
#          Date  Sales  MovingAverage
# 0  2023-09-01    100          100.0
# 1  2023-09-02    150          125.0
# 2  2023-09-03    200          150.0
# 3  2023-09-04    250          175.0
# 4  2023-09-05    300          200.0
# 5  2023-09-06    350          225.0
# 6  2023-09-07    400          250.0

# %% [markdown]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.
# For example, if df contains the following values:
# Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05
# Your function should create the following DataFrame:
#
# Date Weekday
# 0 2023-01-01 Sunday
# 1 2023-01-02 Monday
# 2 2023-01-03 Tuesday
# 3 2023-01-04 Wednesday
# 4 2023-01-05 Thursday
# The function should return the modified DataFrame.

# %%
def weekdays(df):

  df['Date'] = pd.to_datetime(df['Date']) # to convert into proper format if not already

  df['Weekday'] = df['Date'].dt.strftime('%A') # using pandas dt accessor to change Date to  'string format time' format
  #  %A is a format code to get fully weekday name

  return df

df = pd.DataFrame(data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']})

weekdays(df)
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
def get_date(df):
  df['Date'] = pd.to_datetime(df['Date'])

  Start_time = '2023-01-01'
  End_time = '2023-01-31'

  df = df[(df['Date'] >= Start_time) & (df['Date'] <= End_time)]
  return df

df = pd.DataFrame(data = {'Date': ['2023-01-01', '2023-01-15', '2023-01-31', '2023-02-05', '2023-02-28']}
)
get_date(df)
# Out:
#         Date
# 0 2023-01-01
# 1 2023-01-15
# 2 2023-01-31

# %% [markdown]
# Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported?

# %%
# pandas itself
# --> import pandas as pd
